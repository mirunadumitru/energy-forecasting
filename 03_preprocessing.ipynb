# %%
import pandas as pd
from pathlib import Path

RAW = Path("data/raw/energydata_complete.csv")
PROCESSED_DIR = Path("data/processed")
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

df = pd.read_csv(RAW, parse_dates=["date"], skipinitialspace=True)
print(df.shape, df.dtypes[:5])
df.head()
# Out:
# (19735, 29) date          datetime64[ns]
# Appliances             int64
# lights                 int64
# T1                   float64
# RH_1                 float64
# dtype: object
#                  date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0 2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1 2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2 2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3 2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4 2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2    92.0   6.333333   55.333333        5.1  28.642668  28.642668
# 3    92.0   6.000000   51.500000        5.0  45.410389  45.410389
# 4    92.0   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
df["hour"] = df["date"].dt.hour
df["day"] = df["date"].dt.day
df["month"] = df["date"].dt.month
df["day_of_week"] = df["date"].dt.dayofweek

def get_season(m):
    if m in (12, 1, 2):  return "winter"
    if m in (3, 4, 5):   return "spring"
    if m in (6, 7, 8):   return "summer"
    return "autumn"

df["season"] = df["month"].apply(get_season)

df = pd.get_dummies(df, columns=["season"], drop_first=True)

df[["date","hour","day_of_week","month"] + [c for c in df.columns if c.startswith("season_")]].head()
# Out:
#                  date  hour  day_of_week  month  season_winter  season_winter  \
# 0 2016-01-12 17:00:00    17            1      1           True           True
# 1 2016-01-12 17:10:00    17            1      1           True           True
# 2 2016-01-12 17:20:00    17            1      1           True           True
# 3 2016-01-12 17:30:00    17            1      1           True           True
# 4 2016-01-12 17:40:00    17            1      1           True           True
#
#    season_winter  season_winter
# 0           True           True
# 1           True           True
# 2           True           True
# 3           True           True
# 4           True           True

# %%
TARGET = "Appliances"
lags = [1, 6, 24, 72, 144]
for L in lags:
    df[f"{TARGET}_lag_{L}"] = df[TARGET].shift(L)

df[f"{TARGET}_roll6_mean"] = df[TARGET].rolling(window=6).mean()    
df[f"{TARGET}_roll24_mean"] = df[TARGET].rolling(window=24).mean()  
df[f"{TARGET}_roll144_mean"] = df[TARGET].rolling(window=144).mean() 

before = len(df)
df = df.dropna().reset_index(drop=True)
after = len(df)
df.filter(regex="Appliances(_lag_|_roll)").head()
# Out:
#    Appliances_lag_1  Appliances_lag_6  Appliances_lag_24  Appliances_lag_72  \
# 0              40.0              30.0               60.0               50.0
# 1              60.0              40.0              290.0               50.0
# 2              60.0              50.0              130.0               40.0
# 3             210.0              40.0              140.0               40.0
# 4             380.0              40.0              240.0               40.0
#
#    Appliances_lag_144  Appliances_roll6_mean  Appliances_roll24_mean  \
# 0                60.0              45.000000               91.250000
# 1                60.0              48.333333               81.666667
# 2                50.0              75.000000               85.000000
# 3                50.0             131.666667               95.000000
# 4                60.0             186.666667              100.416667
#
#    Appliances_roll144_mean
# 0               104.097222
# 1               104.097222
# 2               105.208333
# 3               107.500000
# 4               109.652778
